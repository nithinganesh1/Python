# %% [markdown]
# # Mall Customers

# %%
import pandas as pd
data=pd.read_csv(r"E:\PYTHON\python Datasets\Mall_Customers.csv")

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data.rename(columns={'Annual Income (k$)': 'Annual_income','Spending Score (1-100)':'SC'},inplace=True)

# %%
data.head(1)
# Out:
#    CustomerID Gender  Age  Annual_income  SC
# 0           1   Male   19             15  39

# %%
plt.scatter(data.Annual_income,data.SC,data.Age,c=data.SC,cmap='winter')
plt.colorbar()
plt.show()

# %% [markdown]
# based on this i clustring in 5 groups

# %%
plt.plot(data['Annual_income'])
plt.show()

# %%
sns.countplot(x=data.Gender)
plt.show()

# %%
sns.barplot(x=data['Gender'],y=data['SC'])
plt.show()

# %%
sns.displot(data.Annual_income,kde=True,color='green')
plt.show()

# %%
sns.pairplot(data=data,hue='SC')
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
data.drop(columns=['CustomerID','Gender'],axis=1,inplace=True)
data.head()
# Out:
#    Age  Annual_income  SC
# 0   19             15  39
# 1   21             15  81
# 2   20             16   6
# 3   23             16  77
# 4   31             17  40

# %%
from sklearn.cluster import k_means
X = data[['Annual_income', 'SC']].values
model = KMeans(n_clusters=5).fit(X)

# %%
labels = model.labels_
centers = model.cluster_centers_

plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(centers[:, 0], centers[:, 1], c='red')

plt.xlabel('Annual Income')
plt.ylabel('SC')
plt.title('KMeans Clustering Results')

plt.show()
