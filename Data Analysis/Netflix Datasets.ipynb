# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv(r"E:\PYTHON\python Datasets\8. Netflix Dataset.csv")
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.notnull().sum()
# Out:
# Show_Id         7789
# Category        7789
# Title           7789
# Director        5401
# Cast            7071
# Country         7282
# Release_Date    7779
# Rating          7782
# Duration        7789
# Type            7789
# Description     7789
# dtype: int64

# %%
data.describe().T
# Out:
#              count unique                                                top  \
# Show_Id       7789   7787                                              s6621
# Category      7789      2                                              Movie
# Title         7789   7787                                  The Lost Okoroshi
# Director      5401   4050                             Raúl Campos, Jan Suter
# Cast          7071   6831                                 David Attenborough
# Country       7282    681                                      United States
# Release_Date  7779   1565                                    January 1, 2020
# Rating        7782     14                                              TV-MA
# Duration      7789    216                                           1 Season
# Type          7789    492                                      Documentaries
# Description   7789   7769  Multiple women report their husbands as missin...
#
#               freq
# Show_Id          2
# ...

# %%
data.nunique()
# Out:
# Show_Id         7787
# Category           2
# Title           7787
# Director        4050
# Cast            6831
# Country          681
# Release_Date    1565
# Rating            14
# Duration         216
# Type             492
# Description     7769
# dtype: int64

# %%
data.Category.unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
data.Category.value_counts()
# Out:
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data.Category)
# Out:
# C:\Users\Nithin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
 data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (7787, 11)

# %%
data[(data.duplicated())]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
## For the " House Of Cards " What is the show id and who is the dirctor of the show

# %%
data[(data.Title.str.contains('House of Cards'))].Director
# Out:
# 2832    Robin Wright, David Fincher, Gerald McRaney, J...
# Name: Director, dtype: object

# %%
data[(data.Title.str.contains('House of Cards'))].Show_Id
# Out:
# 2832    s2833
# Name: Show_Id, dtype: object

# %%
data[(data.Title.str.contains('House of Cards'))]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## Which year highest no of tv series and movise were relesed

# %%
data.Release_Date.dtype
# Out:
# dtype('O')

# %%
data.Release_Date=pd.to_datetime(data.Release_Date)

# %%
data.Release_Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.groupby(data.Release_Date.dt.year).Category.count()
# Out:
# Release_Date
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0      11
# 2014.0      25
# 2015.0      88
# 2016.0     443
# 2017.0    1225
# 2018.0    1685
# 2019.0    2153
# 2020.0    2009
# 2021.0     117
# Name: Category, dtype: int64

# %%
data.groupby(data.Release_Date.dt.year).Category.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Release_Date'>

# %% [markdown]
# ## Making Separate year column  for further calculation

# %%
data['year']=data.Release_Date.dt.year

data.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dc=data.groupby('Category').year.value_counts()

# %%
data.groupby('Category').year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category,year'>

# %%
a=dc.loc['Movie']
b=dc.loc['TV Show']

# %%
a
# Out:
#         year
# year
# 2019.0  1497
# 2020.0  1312
# 2018.0  1255
# 2017.0   864
# 2016.0   258
# 2021.0    88
# 2015.0    58
# 2014.0    19
# 2011.0    13
# 2013.0     6
# 2012.0     3
# 2009.0     2
# 2008.0     1
# 2010.0     1

# %%
b
# Out:
#         year
# year
# 2020.0   697
# 2019.0   656
# 2018.0   430
# 2017.0   361
# 2016.0   185
# 2015.0    30
# 2021.0    29
# 2014.0     6
# 2013.0     5
# 2008.0     1

# %%
year_c=pd.merge(a, b, left_index=True, right_index=True)

# %%
year_c.rename(columns={'year_x':'Movies','year_y':'Tv Shows'}, inplace=True)

# %%
year_c
# Out:
#         Movies  Tv Shows
# year
# 2019.0    1497       656
# 2020.0    1312       697
# 2018.0    1255       430
# 2017.0     864       361
# 2016.0     258       185
# 2021.0      88        29
# 2015.0      58        30
# 2014.0      19         6
# 2013.0       6         5
# 2008.0       1         1

# %%
year_c.plot(kind='bar')
plt.show()

# %%
year_c.plot(kind='bar',stacked=True)
plt.show()

# %% [markdown]
# ## Show All the movies realesed in 2012

# %%
data[(data.Category=='Movie') & (data.year==2012)]
# Out:
#      Show_Id Category                              Title         Director  \
# 818     s819    Movie  Being Elmo: A Puppeteer's Journey  Constance Marks
# 1229   s1230    Movie                   Casa de mi Padre    Matt Piedmont
# 3466   s3467    Movie             Kung Fu Panda: Holiday      Tim Johnson
#
#                                                    Cast  \
# 818                        Kevin Clash, Whoopi Goldberg
# 1229  Will Ferrell, Gael García Bernal, Diego Luna, ...
# 3466  Jack Black, Angelina Jolie, Dustin Hoffman, Ja...
#
#                     Country Release_Date Rating Duration  \
# 818           United States   2012-02-21     PG   76 min
# 1229  United States, Mexico   2012-11-14      R   84 min
# 3466          United States   2012-12-01  TV-PG   26 min
#
#                                     Type  \
# 818                        Documentaries
# 1229                            Comedies
# 3466  Children & Family Movies, Comedies
#
# ...

# %% [markdown]
# ## show all the record of tv shows relesed in India

# %%
data[(data.Category=='TV Show') & (data.Country=='India')]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country Release_Date  \
# ...

# %% [markdown]
# ## only title

# %%
data[(data.Category=='TV Show') & (data.Country=='India')].Title
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ## Top 10 Directors who gave highst no TV Shows and Movies

# %%
data.Director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ## show all the record category Movie and (type Comedies or Country India)

# %%
data[(data.Category=='Movie') & ((data.Type=='Comedies') | (data.Country=='India'))]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country Release_Date  \
# ...

# %% [markdown]
# ## How many movies/shows Tom CruiseFwas cast

# %%
data[(data.Cast=='Tom Cruise')] # need st.contains
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %%
new_data=data.dropna()

# %%
new_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...

# %%
new_data[(new_data.Cast.str.contains('Tom Cruise'))]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %%
len(new_data[(new_data.Cast.str.contains('Tom Cruise'))])
# Out:
# 2

# %% [markdown]
# ## What are the different rationg by Netflix

# %%
data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data.Rating.nunique()
# Out:
# 14

# %% [markdown]
# ## How many TV Show get R rating 2018 and after

# %%
data[(data.Rating=='R') & (data.year>=2018) & (data.Category=='TV Show')]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description    year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %%
data[(data.Rating=='R') & (data.year>=2018) & (data.Category=='TV Show')].shape
# Out:
# (1, 12)

# %% [markdown]
# ## Howmany Movies got 'TV-14' rating in United States

# %%
data[(data.Rating=='TV-14') & (data.Country=='United States') & (data.Category=='Movie')]
# Out:
#      Show_Id Category                                     Title  \
# 33       s34    Movie                              #realityhigh
# 47       s48    Movie                             1 Mile to You
# 56       s57    Movie  100 Years: One Woman's Fight for Justice
# 184     s185    Movie    A Haunting at Silver Falls: The Return
# 223     s224    Movie                             A Secret Love
# ...      ...      ...                                       ...
# 7563   s7562    Movie                        What Still Remains
# 7571   s7570    Movie               What Would Sophia Loren Do?
# 7588   s7587    Movie                         When We First Met
# 7644   s7643    Movie                                  Wish Man
# 7664   s7663    Movie                                   Work It
#
#               Director                                               Cast  \
# 33    Fernando Lebrija  Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
data[(data.Rating=='TV-14') & (data.Country=='United States') & (data.Category=='Movie')].shape
# Out:
# (200, 12)

# %% [markdown]
# ## What is the maximum dutation of Movies/Shows

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data[['duration','unit']] = data.Duration.str.split(' ',expand=True) ## making duration and unit separate

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description    year duration     unit
# 0  In a future where the elite inhabit an island ...  2020.0        4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...  2016.0       93      min

# %%
data.duration.dtype
# Out:
# dtype('O')

# %%
data.duration=pd.to_numeric(data.duration)

# %%
data[(data.duration==data.duration.max()) & (data.unit=='min')]
# Out:
#     Show_Id Category                       Title Director  \
# 957    s958    Movie  Black Mirror: Bandersnatch      NaN
#
#                                                   Cast        Country  \
# 957  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#     Release_Date Rating Duration  \
# 957   2018-12-28  TV-MA  312 min
#
#                                                Type  \
# 957  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                            Description    year  duration unit
# 957  In 1984, a young programmer begins to question...  2018.0       312  min

# %%
data.duration.max()
# Out:
# 312

# %% [markdown]
# ## Which individual cuntry has highest no of tv shows

# %%
data[(data.Category=='TV Show')].Country.value_counts().head()
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: Country, dtype: int64

# %% [markdown]
# ## Find Movie = Dramas or TV Shows Type is 'Kids TV'

# %%
data[((data.Category=='Movie') & (data.Type=='Dramas'))  |  ((data.Category=='TV Show') & (data.Type.str.contains("Kids' TV"))) ]
# Out:
#      Show_Id Category                     Title        Director  \
# 4         s5    Movie                        21  Robert Luketic
# 7         s8    Movie                       187  Kevin Reynolds
# 108     s109  TV Show  3Below: Tales of Arcadia             NaN
# 111     s112  TV Show                   44 Cats             NaN
# 170     s171    Movie              A Family Man   Mark Williams
# ...      ...      ...                       ...             ...
# 7758   s7757  TV Show                        Z4             NaN
# 7761   s7760  TV Show                 Zak Storm             NaN
# 7768   s7767  TV Show              Zig & Sharko             NaN
# 7777   s7776  TV Show                Zoids Wild             NaN
# 7779   s7778  TV Show               Zombie Dumb             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...

# %% [markdown]
# ## sort the dataset by year

# %%
data.sort_values('year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...
